# %%
with open("file.txt","w") as file:
    file.write("101 , Rahul,50000\n")
    file.write("102 , Priya,60000\n")

with open("file.txt","r") as file:
    print(file.read())



with open("file.txt","r") as file:
    print(file.read(5))
    file.seek(10)
    print(file.read(10))
    file.seek(0)
    print(file.readline())
    print(file.readlines())
# Out:
# 101 , Rahul,50000
# 102 , Priya,60000
#
# 101 ,
# l,50000
# 10
# 101 , Rahul,50000
#
# ['102 , Priya,60000\n']
