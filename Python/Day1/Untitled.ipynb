# %%
year = 2026
year = int(input("Please enter the year : "))
print("You Selected :",year)
# Out:
# Please enter the year :  2025
# You Selected : 2025

# %%
num1 = int(input("Enter your first number :"))
num2 = int(input("Enter your second numer :"))
operation = int(input("For + Use 1 , For - Use 2 , For * Use 3 , For / use 4"))
if(operation == 1):
    print(num1 + num2)
elif(operation == 2):
    print(num1 - num2)
elif(operation == 3):
    print(num1 * num2)
elif(operation == 4):
    print(nume1 / num2)
elif(operation == 5):
    print()
else:
    print("No valid operation")
# Out:
# Enter your first number : 5
# Enter your second numer : 5
# For + Use 1 , For - Use 2 , For * Use 3 , For / use 4 1
# 10
