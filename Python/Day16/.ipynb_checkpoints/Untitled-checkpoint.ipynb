# %% [markdown]
# **OOPS**

# %%
class Book:
    def __init__(self,title,author,price):
        self.title = title
        self.author = author
        self.price = price

    def display_info(self):
        print(f"Title: {self.title}\nAuthor:{self.author}\nPrice: {self.price}")

b1 = Book("Harry Potter","JK Rowling","650")
b1.display_info()
# Out:
# Title: Harry Potter
# Author:JK Rowling
# Price: 650

# %%
class student:
    def __init__(self,roll_no,name,marks):
        self.roll_no = roll_no
        self.name = name
        self.marks = marks

    def get_grade(self):
        if(self.marks >= 90):
            print("A")
        elif(self.marks >= 75):
            print("B")
        else:
            print("C")

s1 = student("Rahul",12,50)
s1.get_grade()
# Out:
# C

# %%
class car:
    def __init__(self):
        print("Car Created")
    def __del__(self):
        print("Car destroyed")

c1 = car()
del c1;
# Out:
# Car Created
# Car destroyed

# %%
class rectangle:
    def __init__(self,length,width):
        self.length = length
        self.width = width

    def area(self):
        print(self.length * self.width)

    def perimeter(self):
        print(2*(self.length+self.width))

r1 = rectangle(10,5)
r1.area()
r1.perimeter()
# Out:
# 50
# 30

# %%
class employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary

    def give_raise(self,percent):
        print(self.salary + (self.salary * (percent/100)))

emp1 = employee("ram",12000)
emp1.give_raise(100)
# Out:
# 24000.0

# %%
class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def show_all_books(self):
        for book in self.books:
            book.display_info()


class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display_info(self):
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Price: {self.price}")
        print()


b1 = Book("Harry Potter", "JK Rowling", 650)
b2 = Book("Atomic Habits", "James Clear", 500)
b3 = Book("Ikigai", "Hector Garcia", 400)

library = Library()

library.add_book(b1)
library.add_book(b2)
library.add_book(b3)

library.show_all_books()
# Out:
# Title: Harry Potter
# Author: JK Rowling
# Price: 650
#
# Title: Atomic Habits
# Author: James Clear
# Price: 500
#
# Title: Ikigai
# Author: Hector Garcia
# Price: 400

# %% [markdown]
# **Encapsulation**

# %%
class Employee:
    def __init__(self):
        self.__salary = 10000

    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, value):
        if value < 0:
            print("Invalid salary")
        else:
            self.__salary = value

    def apply_raise(self, percent):
        new_salary = self.salary + (self.salary * (percent / 100))
        self.salary = new_salary


e1 = Employee()

print(e1.salary)

e1.salary = 12000
print(e1.salary)
e1.apply_raise(10)

print(e1.salary)
# Out:
# 10000
# 12000
# 13200.0
