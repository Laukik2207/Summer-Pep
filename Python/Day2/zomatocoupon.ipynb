# %%
orderMonth = int(input("Enter number of orders in current month :"))
MonthTotal = int(input("Enter the total of current month order values :"))
orderDay = int(input("Enter number of orders of the day :"))

if(orderDay > 3):
    print("Great! you have got upto 50rs off on your next order")
elif(orderDay > 5):
    print("Great! you have got upto 100rs off on your next order")
elif(MonthTotal > 1000):
    print("Get upto 10% off on your next order")
elif(MonthTotal > 2500):
    print("Get upto 25% off on your next order")
elif(MonthTotal > 5000):
    print("Bravoo! you have got a exclusive 50% off on your next order")
elif(orderMonth > 20):
    print("Get upto 10% off on your next order")
else:
    print("Sorry but we don't have any coupons for you right now! Come back later and we will have something for you")
# Out:
# Enter number of orders in current month : 20
# Enter the total of current month order values : 1000
# Enter number of orders of the day : 2
# Sorry but we don't have any coupons for you right now! Come back later and we will have something for you
