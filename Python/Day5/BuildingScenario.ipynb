# %%
b = int(input("Enter Buildings: "))
for i in range(1,b+1):
    print("Current Building: ",i)
    f = int(input("Enter no. of floors"))
    for j in range(1,f+1):
        print("Current Floor: ",j)
        r = int(input("Enter no. of rooms"))
        for k in range(1,r+1):
            print("Deliverd the Medicines in room: ",k,end=" \n")
        print()
    print()
# Out:
# Enter Buildings:  1
# Current Building:  1
# Enter no. of floors 2
# Current Floor:  1
# Enter no. of rooms 2
# Deliverd the Medicines in room:  1
# Deliverd the Medicines in room:  2
#
# Current Floor:  2
# Enter no. of rooms 5
# Deliverd the Medicines in room:  1
# Deliverd the Medicines in room:  2
# Deliverd the Medicines in room:  3
# Deliverd the Medicines in room:  4
# Deliverd the Medicines in room:  5
