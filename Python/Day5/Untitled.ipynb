# %% [markdown]
# What is a three level Nested Loop

# %%
Inner Loop inside another loop inside another loop

# %%
Inner loop changes the fatest

# %%
Outer Loop is the slowest

# %%
True - The middle loop starts only after outer loop

# %%
False - Outer loop cannot finish before inner loop

# %%
Country -> State -> City

# %%
3 Loops are required

# %%
125

# %%
School -> Teacher -> Student

# %%
000
